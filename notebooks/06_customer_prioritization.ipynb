# %% [markdown]
# # About

# %% [markdown]
# **Original Question**:
# Say the budget is only enough to retain 20% base customers, how should this customer set be chosen?
# Strategies to compare:
# - High churn probability (classification)
# - Low P(alive) (BG-NBD)
# - High CLV * High churn risk (Survival-based)
#
# **Answer**:
# - *Before any analysis of results*: I would choose the High churn probability approach using a Classifier.
#     - Better prediction performance:
#         - Churn prediction: Although longer predictions have terrible recall, smaller prediction windows show excellent results. This can be because of the volatility of the data.
#         - CLV prediction: Results from Gamma-Gamma prediction have quite large MAE, so I rather be more certain than unnecessary prevention by assigning more weight to Gamma-Gamma's predictions.
#     - Action-oriented: Unlike BG-NBD where probability of being alive is evaluated right after the observation period, a Classifier gives us a future outlook where we can plan for. Again, businesses need time to gather resources. Sometimes, the BG-NBD model shows customer p_alive already >0.4, and they may have well already churned before we can do anything.

# %% [markdown]
# # Preparation

# %% [markdown]
# ## Libraries

# %%
from dotenv import load_dotenv
import os
from pathlib import Path
import joblib

# %%
import tempfile
import cloudpickle

# %%
import mlflow

# %%
import pandas as pd

# %%
import numpy as np

# %%
PROJECT_ROOT = Path.cwd().parent

# %%
BASE_GOLD_DIR = PROJECT_ROOT / "data" / "gold" / "31_12_2025"

# %%
MLRUNS_DIR = PROJECT_ROOT / "mlruns"
EXPERIMENT_NAME = "customer_lifetime_modeling"
mlflow.set_tracking_uri(f"file://{MLRUNS_DIR}")
from mlflow.tracking import MlflowClient

client = MlflowClient()

# %% [markdown]
# ## Wrappers

# %% [markdown]
# ### Load Data

# %%
def load_features(
        dataset_version,
        features_path,
        targets=['is_churn_30_days', 'is_churn_60_days', 'is_churn_90_days']
    ):
    '''
        The service preloads the feature dataframes for faster search.
    '''

    if dataset_version == "raw":
        feature_df = pd.read_csv(features_path/ "classifier" / "raw" / "features.csv", index_col=0)
        return feature_df
    elif dataset_version == "transformed":
        X_by_target = {}
        for target in targets:
            feature_df = pd.read_csv(features_path/ "classifier" / "transformed" / target / "features.csv", index_col=0)
            X_by_target[target] = feature_df
        return X_by_target
    else:
        return "Invalid dataset version. Please use only `raw` and `transformed`."

# %%
def get_customer_features(
    customer_ids,
    target,
    metadata,
    raw_features_df,
    transformed_features_by_target,
):
    if isinstance(customer_ids, str):
        customer_ids = [customer_ids]

    dataset_version = metadata[target]["dataset_version"]

    if dataset_version == "raw":
        X = raw_features_df.loc[customer_ids]
    elif dataset_version == "transformed":
        X = transformed_features_by_target[target].loc[customer_ids]
    else:
        raise ValueError(f"Unknown dataset version: {dataset_version}")

    return X

# %% [markdown]
# ### Load Models

# %%
def load_models_once():
    if MODEL_STORE:
        return  # already loaded

    MODEL_STORE["ggf"], MODEL_STORE["ggf_meta"] = load_gamma_gamma_model()
    MODEL_STORE["bgf"], MODEL_STORE["bgf_meta"] = load_bg_nbd_model()
    MODEL_STORE["survival"], MODEL_STORE["survival_meta"] = load_survival_analysis_model()

# %%
def load_churn_classifiers():

    exp = mlflow.get_experiment_by_name("churn_prediction")
    if exp is None:
        raise ValueError(f"Experiment {exp} not found")
    
    runs = mlflow.search_runs(
        experiment_ids=[exp.experiment_id],
        filter_string="tags.stage = 'production'",
        output_format="pandas",
    )

    if runs.empty:
        raise ValueError("No production run found")

    models = {}
    metadata = {}

    for _, row in runs.iterrows():
        target = row["params.target"]
        dataset_version = row["params.dataset_version"]
        run_id = row["run_id"]

        model_uri = f"runs:/{run_id}/{dataset_version}_{target}"
        model = mlflow.lightgbm.load_model(model_uri)

        models[target] = model
        metadata[target] = {
            "dataset_version": dataset_version,
            "run_id": run_id,
        }

    return models, metadata

# %%
def load_bg_nbd_model(exp_name="customer_activity_modeling"):
    exp = mlflow.get_experiment_by_name(exp_name)
    if exp is None:
        raise ValueError(f"Experiment {exp_name} not found")

    runs = mlflow.search_runs(
        experiment_ids=[exp.experiment_id],
        filter_string="tags.stage = 'production'",
        output_format="pandas",
    )

    if runs.empty:
        raise ValueError("No production BG-NBD run found")

    run = runs.iloc[0]
    run_id = run["run_id"]

    metadata = {
        "run_id": run_id,
        "experiment_id": exp.experiment_id,
        "experiment_name": exp.name,
        "params": run.filter(like="params.").to_dict(),
        "metrics": run.filter(like="metrics.").to_dict(),
        "tags": run.filter(like="tags.").to_dict(),
    }

    with tempfile.TemporaryDirectory() as d:
        local_path = mlflow.artifacts.download_artifacts(
            run_id=run_id,
            artifact_path="model/model.pkl",
            dst_path=d,
        )

        with open(local_path, "rb") as f:
            model = cloudpickle.load(f)

    return model, metadata

# %%
def load_survival_analysis_model():
    exp = mlflow.get_experiment_by_name("customer_lifetime_modeling")
    if exp is None:
        raise ValueError(f"Experiment {exp} not found")

    runs = mlflow.search_runs(
        experiment_ids=[exp.experiment_id],
        filter_string="tags.stage = 'production'",
        output_format="pandas",
    )

    if runs.empty:
        raise ValueError("No production run found")

    run = runs.iloc[0]
    run_id = run["run_id"]

    metadata = {
        "run_id": run_id,
        "experiment_id": exp.experiment_id,
        "experiment_name": exp.name,
        "params": run.filter(like="params.").to_dict(),
        "metrics": run.filter(like="metrics.").to_dict(),
        "tags": run.filter(like="tags.").to_dict(),
    }

    with tempfile.TemporaryDirectory() as d:

        path = mlflow.artifacts.download_artifacts(
            run_id=run_id,
            artifact_path="model/model.pkl",
            dst_path=d,
        )
        model = cloudpickle.load(open(path, "rb"))

    return model, metadata

# %%
def load_gamma_gamma_model():
    exp = mlflow.get_experiment_by_name("customer_monetary_modeling")
    if exp is None:
        raise ValueError(f"Experiment {exp} not found")

    runs = mlflow.search_runs(
        experiment_ids=[exp.experiment_id],
        filter_string="tags.stage = 'production'",
        output_format="pandas",
    )

    if runs.empty:
        raise ValueError("No production run found")

    run = runs.iloc[0]
    run_id = run["run_id"]

    metadata = {
        "run_id": run_id,
        "experiment_id": exp.experiment_id,
        "experiment_name": exp.name,
        "params": run.filter(like="params.").to_dict(),
        "metrics": run.filter(like="metrics.").to_dict(),
        "tags": run.filter(like="tags.").to_dict(),
    }

    with tempfile.TemporaryDirectory() as d:

        path = mlflow.artifacts.download_artifacts(
            run_id=run_id,
            artifact_path="model/model.pkl",
            dst_path=d,
        )
        model = cloudpickle.load(open(path, "rb"))

    return model, metadata

# %% [markdown]
# ### Inference

# %%
def load_models_once():
    if MODEL_STORE:
        return  # already loaded

    MODEL_STORE["ggf"], MODEL_STORE["ggf_meta"] = load_gamma_gamma_model()
    MODEL_STORE["bgf"], MODEL_STORE["bgf_meta"] = load_bg_nbd_model()
    MODEL_STORE["survival"], MODEL_STORE["survival_meta"] = load_survival_analysis_model()

# %%
def predict_churns(
    customer_ids: list[str],
    horizon_days: int,
    raw_features_df,
    transformed_features_by_target,
    models,
    metadata,
):
    # ------------------
    # Validate horizon
    # ------------------
    if horizon_days not in {30, 60, 90}:
        raise ValueError("horizon_days must be one of {30, 60, 90}")

    target = f"is_churn_{horizon_days}_days"

    if target not in models:
        raise KeyError(f"No production model loaded for target: {target}")

    # ------------------
    # Feature extraction (BULK)
    # ------------------
    X = get_customer_features(
        customer_ids=customer_ids,
        target=target,
        metadata=metadata,
        raw_features_df=raw_features_df,
        transformed_features_by_target=transformed_features_by_target,
    )

    # ------------------
    # Predict (BULK)
    # ------------------
    model = models[target]
    churn_probs = model.predict_proba(
        X,
        predict_disable_shape_check=True
    )[:, 1]

    # ------------------
    # Risk labeling (vectorized)
    # ------------------
    churn_labels = np.where(
        churn_probs >= 0.7,
        "high_risk",
        np.where(
            churn_probs >= 0.4,
            "medium_risk",
            "low_risk",
        ),
    )

    # ------------------
    # Output (aligned, explicit)
    # ------------------
    return (
        pd.DataFrame(
            {
                "customer_id": customer_ids,
                "churn_probability": churn_probs.round(4),
                "churn_label": churn_labels,
            }
        )
        .set_index("customer_id")
    )

# %%
def predict_n_purchase_bg_nbd(
    X,
    bgf,
    t=30
):
    X["n_purchase"] = bgf.conditional_expected_number_of_purchases_up_to_time(
        t=t,
        frequency=X["frequency"],
        recency=X["recency"],
        T=X["T"]
    )

    X = X.rename(columns={'n_purchase': f'pred_n_purchase_{t}d'})

    return X

# %%
def predict_p_alive_churn_bg_nbd(
    X,
    bgf
):
    X["p_alive"] = bgf.conditional_probability_alive(
        X["frequency"],
        X["recency"],
        X["T"]
    )

    X["p_churn"] = 1 - X["p_alive"]

    return X

# %%
def predict_users_bg_nbd(
    customer_ids: pd.Series | list[str],
    horizon_days: int,
    summary_df: pd.DataFrame,
    model,
) -> pd.DataFrame:

    customer_ids = pd.Index(customer_ids)

    X = summary_df.loc[summary_df.index.intersection(customer_ids)]

    if X.empty:
        raise ValueError("No matching customers found for BG/NBD prediction")

    p_alive = predict_p_alive_churn_bg_nbd(X, model)["p_alive"]
    n_purchase = predict_n_purchase_bg_nbd(
        X, model, t=horizon_days
    )[f"pred_n_purchase_{horizon_days}d"]

    return pd.DataFrame(
        {
            "p_alive": p_alive.round(4),
            f"pred_n_purchase_{horizon_days}d": n_purchase,
        },
        index=X.index,
    )

# %%
def predict_users_survival(
    customer_ids: list[str],
    survival_df: pd.DataFrame,
    model,
    horizons: list[int] = [30, 60, 90],
) -> pd.DataFrame:
    """
    Returns survival probabilities at given horizons
    + expected remaining lifetime for multiple users.
    """

    # -------------------
    # Slice rows
    # -------------------
    X_raw = survival_df.loc[customer_ids]

    if X_raw.empty:
        raise ValueError("No matching customers found")

    # -------------------
    # Feature matrix
    # -------------------
    X = X_raw.drop(columns=["customer_id", "T", "E"], errors="ignore")

    # -------------------
    # Survival function
    # -------------------
    surv_fn = model.predict_survival_function(X)
    # rows = time, cols = customers

    # -------------------
    # Horizon extraction
    # -------------------
    out = {}

    for h in horizons:
        # last survival prob before horizon h
        idx = surv_fn.index <= h

        if not idx.any():
            probs = surv_fn.iloc[0]
        else:
            probs = surv_fn.loc[idx].iloc[-1]

        out[f"survival_p_{h}d"] = probs.values

    # -------------------
    # Expected remaining lifetime
    # -------------------
    expected_lifetime = model.predict_expectation(X).values

    # -------------------
    # Output DF
    # -------------------
    result = pd.DataFrame(
        out,
        index=X_raw.index,
    )

    result["expected_remaining_lifetime"] = expected_lifetime.round(2)

    return result.round(4)

# %%
def predict_survival_clv(
    survival_model,
    ggf,
    X,
    horizon_days=30,
    frequency_col="period_transaction_count",
    tenure_col="T"
):
    surv = survival_model.predict_survival_function(X)

    expected_aov = ggf.conditional_expected_average_profit(
        X["period_transaction_count"],
        X["period_total_amount"],
    )

    lambda_rate = X[frequency_col] / X[tenure_col]

    clv = []
    for i in range(len(X)):
        s = surv.iloc[:, i]
        s = s.loc[s.index <= horizon_days]

        clv_i = (
            expected_aov.iloc[i]
            * lambda_rate.iloc[i]
            * s.sum()
        )
        clv.append(clv_i)

    return pd.Series(clv, index=X.index)

# %%
def estimate_users_clv(
    customer_ids: list[str],
    method: str,
    horizon_days: int = 30,
    BASE_GOLD_DIR: str = BASE_GOLD_DIR,
) -> pd.DataFrame:

    load_models_once()  # no-op after first call

    ggf = MODEL_STORE["ggf"]

    if method == "bgnbd":
        bgf = MODEL_STORE["bgf"]

        input_path = (
            BASE_GOLD_DIR
            / "cut_30d"
            / "features"
            / "clv"
            / "bgf_gg"
            / "raw"
            / "features.csv"
        )

    elif method == "survival":
        survival_model = MODEL_STORE["survival"]

        input_path = (
            BASE_GOLD_DIR
            / "cut_30d"
            / "features"
            / "clv"
            / "survival_gg"
            / "transformed"
            / "features.csv"
        )

    else:
        raise ValueError("method must be 'bgnbd' or 'survival'")

    # -------------------
    # Load + filter data
    # -------------------
    X = pd.read_csv(input_path, index_col="customer_id")
    X = X.loc[X.index.intersection(customer_ids)]

    if X.empty:
        raise ValueError("No matching customers found")

    # -------------------
    # CLV estimation
    # -------------------
    if method == "bgnbd":
        clv = ggf.customer_lifetime_value(
            bgf,
            X["frequency"],
            X["recency"],
            X["T"],
            X["period_total_amount"],
            time=horizon_days,
            discount_rate=0.0,
            freq="D",
        )

    else:
        clv = predict_survival_clv(
            survival_model,
            ggf,
            X,
            horizon_days=horizon_days,
        )

    # -------------------
    # Output
    # -------------------
    result = pd.DataFrame(
        {
            "customer_id": X.index,
            "method": method,
            "clv": clv.astype(float).round(2),
            "horizon_days": horizon_days,
        }
    ).set_index("customer_id")

    return result

# %%
def rank_customers_for_retention(
    strategy: str,
    top_k: int = 100,
    prediction_df: pd.DataFrame | None = None,
):
    if prediction_df is None:
        input_path = (
            BASE_GOLD_DIR
            / "cut_30d"
            / "inference"
            / "all_targets.csv"
        )
        prediction_df = pd.read_csv(input_path, index_col="customer_id")

    df = prediction_df.copy()

    # ---------- sanity checks ----------
    required_cols = {
        "p_churn_classifier_30d",
        "p_churn_survival_30d",
        "p_alive",
        "pred_CLV_survival_30d",
    }
    missing = required_cols - set(df.columns)
    if missing:
        raise ValueError(f"Missing required columns: {missing}")

    # ---------- normalize CLV ----------
    clv = df["pred_CLV_survival_30d"]
    clv_norm = (clv - clv.min()) / (clv.max() - clv.min() + 1e-9)
    df["_clv_norm"] = clv_norm

    # ---------- strategy logic ----------
    if strategy == "high_clv_high_churn_classifier":
        df["priority_score"] = (
            df["_clv_norm"] * df["p_churn_classifier_30d"]
        )
        churn_col = "p_churn_classifier_30d"

    elif strategy == "high_clv_high_churn_survival":
        df["priority_score"] = (
            df["_clv_norm"] * df["p_churn_survival_30d"]
        )
        churn_col = "p_churn_survival_30d"

    elif strategy == "low_p_alive":
        df["priority_score"] = 1.0 - df["p_alive"]
        churn_col = None

    else:
        raise ValueError(f"Unknown strategy: {strategy}")

    # ---------- rank ----------
    ranked = (
        df.sort_values("priority_score", ascending=False)
        .head(top_k)
    )

    # ---------- output formatting ----------
    customers = []
    for customer_id, row in ranked.iterrows():
        customers.append(
            {
                "customer_id": customer_id,
                "churn_probability": (
                    round(float(row[churn_col]), 4)
                    if churn_col is not None
                    else None
                ),
                "clv": round(float(row["pred_CLV_survival_30d"]), 2),
                "priority_score": round(float(row["priority_score"]), 4),
            }
        )

    return {
        "strategy": strategy,
        "customers": customers,
    }

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data Definition

# %% [markdown]
# In the previous notebooks I did lots of transformations to get the right features for each model type. On the event of the final notebook (this notebook), I have manually reorganized the datasets a bit for better inference. When the functions are redefined and models set for production, I will of course write the transformation as code.
#
# gold/<date> means the data used for feature engineering has the end date of <date>. Depending on the training purpose, I will cut the data (30 days, 60 days, 120 days) so I have the correct labels for training. Depending on the model type, I will generate features accordingly.
# They stay in folders such as:
# - classifier (for Churn Classification)
# - bgnbd (for BG/NBD)
# - clv (for Survival/BGNBD and Gamma-Gamma models).
#
# The data structure is illustrated below:
#
# ```
# data/
# ├── archive/
# │
# ├── gold/
# │   └── 31_12_2025/
# │       ├── cut_1d/
# │       │   └── features/
# │       │       └── classifier/
# │       │           ├── raw/
# │       │           ├── target/
# │       │           └── transformed/
# │       │
# │       ├── cut_30d/
# │       │   └── features/
# │       │       └── clv/
# │       │           ├── bgf_gg/
# │       │           └── survival_gg/
# │       │
# │       └── cut_90d/
# │           └── features/
# │               └── classifier/
# │                   ├── raw/
# │                   ├── target/
# │                   └── transformed/
# │
# └── seed/
#     ├── customers.csv
#     └── transactions.csv
# ```

# %% [markdown]
# Which data cut was used to train each **production** model? Let's revise the results.
# - Churn Classifier: cut_90d
# - BGNBD: cut_30d
# - Survival Models: cut_30d
# - Gamma-Gamma Models: cut_30d
#
# However, to make predictions consistent, I will take the cut_30d set for inference for all models.

# %% [markdown]
# ### Load Data

# %%
input_path = (
    BASE_GOLD_DIR
    / "cut_30d"
    / "features"
    / "classifier"
    / "raw"
    / "features.csv"
)

churn_classifier_raw_features = pd.read_csv(input_path, index_col="customer_id")

# %%
input_path = (
    BASE_GOLD_DIR
    / "cut_30d"
    / "features"
)

churn_classifier_transformed_features = load_features(
    dataset_version="transformed",
    features_path=input_path,
    targets=['is_churn_30_days']
)

# %%
input_path = (
    BASE_GOLD_DIR
    / "cut_30d"
    / "features"
    / "clv"
    / "survival_gg"
    / "transformed"
    / "features.csv"
)

survival_features = pd.read_csv(input_path, index_col='customer_id')

# %%
input_path = (
    BASE_GOLD_DIR
    / "cut_30d"
    / "features"
    / "bgnbd"
    / "raw"
    / "features.csv"
)

bgf_features = pd.read_csv(input_path, index_col="customer_id")

# %%
input_path = (
    BASE_GOLD_DIR
    / "cut_30d"
    / "features"
    / "clv"
    / "survival_gg"
    / "transformed"
    / "features.csv"
)

survival_gg_features = pd.read_csv(input_path, index_col="customer_id")

# %%
input_path = (
    BASE_GOLD_DIR
    / "cut_30d"
    / "features"
    / "clv"
    / "bgf_gg"
    / "raw"
    / "features.csv"
)

bgf_gg_features = pd.read_csv(input_path, index_col="customer_id")

# %% [markdown]
# ## Models

# %%
churn_classifiers, churn_classifiers_metadata = load_churn_classifiers()
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
survival_model, survival_model_metadata = load_survival_analysis_model()
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
bgf, bgf_metadata = load_bg_nbd_model()
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
ggf, ggf_metadata = load_gamma_gamma_model()
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # Comparison of Strategies

# %% [markdown]
# ## Revision of Training Metrics

# %% [markdown]
# As can be seen, BGNBD performs the best in terms of recall.
#
# ### Churn Classifier (30 days)
#
# Validation Set
# - ROC AUC: 0.5111
# - PR AUC: 0.5661
# - Precision: 0.5821
# - Recall: 0.5612
# - MAE: 1.5201
#
#
# ### BGNBD Model
#
# Validation Set
# - ROC AUC: 0.9243
# - PR AUC: 0.9544
# - Precision: 0.9577
# - **Recall: 0.7861**
# - MAE: 1.5201
#
# Test Set
# - ROC AUC: 0.8610
# - PR AUC: 0.9156
# - Precision: 0.9532
# - Recall: 0.7022
# - MAE: 1.7437
#
#
# ### Survival Model (Weibull)
#
# Train Set
# - ROC AUC: 0.8001
# - PR AUC: 0.8353
# - Precision: 0.0000
# - Recall: 0.0000
#
# Validation Set
# - ROC AUC: 0.7749
# - PR AUC: 0.8300
# - Precision: 0.0000
# - Recall: 0.0000
#
# Test Set
# - ROC AUC: 0.7703
# - PR AUC: 0.8098
# - Precision: 0.0000
# - Recall: 0.0000
#
#
# ### Gamma-Gamma Model
#
# Train Set
# - param_p: 0.2342
# - param_q: 2.4833
# - param_v: 8189.3504
# - avg_predicted_monetary_value: 1252.4485
# - neg_log_likelihood: 7.6986
# - n_customers_train: 763

# %% [markdown]
# ## Inference

# %% [markdown]
# Instead of inferencing on a set of users, I will just infer for all users, write it some where and use it to choose users.

# %%
MODEL_STORE = {}

# %%
customer_ids = bgf_features.reset_index()['customer_id']
prediction_df = bgf_features.reset_index()[['customer_id']].copy().set_index('customer_id', drop=True)

# %%
## CHURN CLASSIFIER
prediction_df['p_churn_classifier_30d'] = (
    predict_churns(
        customer_ids=customer_ids,
        horizon_days=30,
        raw_features_df=churn_classifier_raw_features,
        transformed_features_by_target=churn_classifier_transformed_features,
        models=churn_classifiers,
        metadata=churn_classifiers_metadata,
    )["churn_probability"]
)

# %%
## BGNBD MODEL
prediction_df['p_alive'] = (
    predict_users_bg_nbd(
        customer_ids=customer_ids,
        horizon_days=30,
        summary_df=bgf_features,
        model=bgf,
    )
    ["p_alive"]
)

# %%
## SURVIVAL MODEL
prediction_df['p_churn_survival_30d'] = (
    predict_users_survival(
        customer_ids=customer_ids,
        survival_df=survival_features,
        model=survival_model,
        horizons=[30],
    )['survival_p_30d']
)

# %%
## CLV (SURVIVAL)
prediction_df['pred_CLV_survival_30d'] = (
    estimate_users_clv(
        customer_ids=customer_ids,
        method="survival",
        horizon_days=30,
        BASE_GOLD_DIR=BASE_GOLD_DIR
    )['clv']
)
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
prediction_df
# Out:
#              p_churn_classifier_30d  p_alive  p_churn_survival_30d  \
# customer_id
# C00000                       0.8382   0.9438                0.9956
# C00001                       0.4603   0.9575                0.9998
# C00002                       0.9127   0.0010                0.9396
# C00003                       0.8104   0.8972                0.9900
# C00004                       0.2179   0.0008                0.9790
# ...                             ...      ...                   ...
# C02995                       0.9071   0.9316                0.9929
# C02996                       0.3845   0.9550                0.9974
# C02997                       0.7498   0.9244                0.9847
# C02998                       0.6005   0.9630                0.9948
# C02999                       0.8652   0.9817                0.9992
#
#              pred_CLV_survival_30d
# customer_id
# C00000                       68.71
# C00001                       57.01
# C00002                      226.17
# C00003                       39.46
# C00004                      302.46
# ...                            ...
# C02995                       68.80
# C02996                       38.66
# C02997                       72.68
# C02998                      133.72
# C02999                      615.81
#
# [2830 rows x 4 columns]

# %% [markdown]
# ## Write Inference Data

# %%
output_path = (
    BASE_GOLD_DIR
    / "cut_30d"
    / "inference"
    / "all_targets.csv"
)

#output_path.parent.mkdir(parents=True, exist_ok=True)

prediction_df.to_csv(output_path, index=True)

# %% [markdown]
# ## Read Inference Data

# %%
input_path = (
    BASE_GOLD_DIR
    / "cut_30d"
    / "inference"
    / "all_targets.csv"
)

prediction_df = pd.read_csv(input_path, index_col="customer_id")

# %%
prediction_df.columns
# Out:
# Index(['p_churn_classifier_30d', 'p_alive', 'p_churn_survival_30d',
#        'pred_CLV_survival_30d'],
#       dtype='object')

# %% [markdown]
# ## Rank Customers

# %%
rank_customers_for_retention(
    strategy="high_clv_high_churn_classifier",
    top_k=100,
    prediction_df=prediction_df,
)
# Out:
# {'strategy': 'high_clv_high_churn_classifier',
#  'customers': [{'customer_id': 'C00158',
#    'churn_probability': 0.5633,
#    'clv': 8614.52,
#    'priority_score': 0.5633},
#   {'customer_id': 'C02473',
#    'churn_probability': 0.6178,
#    'clv': 5681.23,
#    'priority_score': 0.4073},
#   {'customer_id': 'C02914',
#    'churn_probability': 0.9101,
#    'clv': 3568.36,
#    'priority_score': 0.3767},
#   {'customer_id': 'C00763',
#    'churn_probability': 0.9175,
#    'clv': 3285.43,
#    'priority_score': 0.3496},
#   {'customer_id': 'C01277',
#    'churn_probability': 0.6354,
#    'clv': 3833.37,
#    'priority_score': 0.2826},
#   {'customer_id': 'C00789',
#    'churn_probability': 0.9083,
#    'clv': 2493.5,
#    'priority_score': 0.2626},
#   {'customer_id': 'C02934',
#    'churn_probability': 0.9161,
#    'clv': 2391.85,
#    'priority_score': 0.254},
#   {'customer_id': 'C01754',
#    'churn_probability': 0.5104,
#    'clv': 3626.54,
#    'priority_score': 0.2147},
#   {'customer_id': 'C02706',
#    'churn_probability': 0.9115,
#    'clv': 1892.06,
#    'priority_score': 0.1998},
#   {'customer_id': 'C01864',
#    'churn_probability': 0.7021,
#    'clv': 2313.21,
#    'priority_score': 0.1883},
#   {'customer_id': 'C01591',
#    'churn_probability': 0.8784,
#    'clv': 1847.41,
#    'priority_score': 0.188},
#   {'customer_id': 'C02030',
#    'churn_probability': 0.8028,
#    'clv': 1996.79,
#    'priority_score': 0.1858},
#   {'customer_id': 'C02267',
#    'churn_probability': 0.7955,
#    'clv': 2001.81,
#    'priority_score': 0.1845},
#   {'customer_id': 'C01189',
#    'churn_probability': 0.6747,
#    'clv': 2268.08,
#    'priority_score': 0.1774},
#   {'customer_id': 'C02658',
#    'churn_probability': 0.906,
#    'clv': 1676.33,
#    'priority_score': 0.1759},
#   {'customer_id': 'C02865',
#    'churn_probability': 0.6502,
#    'clv': 2284.53,
#    'priority_score': 0.1722},
#   {'customer_id': 'C00423',
#    'churn_probability': 0.8259,
#    'clv': 1759.64,
#    'priority_score': 0.1684},
#   {'customer_id': 'C00599',
#    'churn_probability': 0.8865,
#    'clv': 1626.26,
#    'priority_score': 0.167},
#   {'customer_id': 'C02347',
#    'churn_probability': 0.6266,
#    'clv': 2228.02,
#    'priority_score': 0.1618},
#   {'customer_id': 'C01134',
#    'churn_probability': 0.635,
#    'clv': 2117.58,
#    'priority_score': 0.1558},
#   {'customer_id': 'C01131',
#    'churn_probability': 0.5835,
#    'clv': 2123.12,
#    'priority_score': 0.1436},
#   {'customer_id': 'C00268',
#    'churn_probability': 0.6069,
#    'clv': 2034.38,
#    'priority_score': 0.1431},
#   {'customer_id': 'C00490',
#    'churn_probability': 0.832,
#    'clv': 1465.56,
#    'priority_score': 0.1412},
#   {'customer_id': 'C00325',
#    'churn_probability': 0.9175,
#    'clv': 1311.61,
#    'priority_score': 0.1393},
#   {'customer_id': 'C02905',
#    'churn_probability': 0.8111,
#    'clv': 1431.82,
#    'priority_score': 0.1345},
#   {'customer_id': 'C01793',
#    'churn_probability': 0.6519,
#    'clv': 1763.2,
#    'priority_score': 0.1332},
#   {'customer_id': 'C00421',
#    'churn_probability': 0.5651,
#    'clv': 1888.03,
#    'priority_score': 0.1236},
#   {'customer_id': 'C01024',
#    'churn_probability': 0.813,
#    'clv': 1307.78,
#    'priority_score': 0.1231},
#   {'customer_id': 'C01920',
#    'churn_probability': 0.7055,
#    'clv': 1449.22,
#    'priority_score': 0.1184},
#   {'customer_id': 'C02081',
#    'churn_probability': 0.9175,
#    'clv': 1115.29,
#    'priority_score': 0.1184},
#   {'customer_id': 'C02832',
#    'churn_probability': 0.9101,
#    'clv': 1076.2,
#    'priority_score': 0.1133},
#   {'customer_id': 'C00202',
#    'churn_probability': 0.8091,
#    'clv': 1198.5,
#    'priority_score': 0.1122},
#   {'customer_id': 'C01986',
#    'churn_probability': 0.6388,
#    'clv': 1509.89,
#    'priority_score': 0.1117},
#   {'customer_id': 'C02127',
#    'churn_probability': 0.9101,
#    'clv': 1022.21,
#    'priority_score': 0.1076},
#   {'customer_id': 'C02204',
#    'churn_probability': 0.7631,
#    'clv': 1193.74,
#    'priority_score': 0.1054},
#   {'customer_id': 'C02283',
#    'churn_probability': 0.856,
#    'clv': 1037.43,
#    'priority_score': 0.1027},
#   {'customer_id': 'C02821',
#    'churn_probability': 0.7734,
#    'clv': 1142.07,
#    'priority_score': 0.1022},
#   {'customer_id': 'C00604',
#    'churn_probability': 0.8164,
#    'clv': 1056.64,
#    'priority_score': 0.0998},
#   {'customer_id': 'C00190',
#    'churn_probability': 0.9175,
#    'clv': 928.5,
#    'priority_score': 0.0985},
#   {'customer_id': 'C02156',
#    'churn_probability': 0.6914,
#    'clv': 1228.69,
#    'priority_score': 0.0983},
#   {'customer_id': 'C00988',
#    'churn_probability': 0.9175,
#    'clv': 926.84,
#    'priority_score': 0.0983},
#   {'customer_id': 'C00397',
#    'churn_probability': 0.4743,
#    'clv': 1776.89,
#    'priority_score': 0.0976},
#   {'customer_id': 'C01130',
#    'churn_probability': 0.8209,
#    'clv': 1026.43,
#    'priority_score': 0.0974},
#   {'customer_id': 'C02364',
#    'churn_probability': 0.863,
#    'clv': 940.79,
#    'priority_score': 0.0939},
#   {'customer_id': 'C02014',
#    'churn_probability': 0.5388,
#    'clv': 1493.46,
#    'priority_score': 0.0932},
#   {'customer_id': 'C00530',
#    'churn_probability': 0.8448,
#    'clv': 952.91,
#    'priority_score': 0.0931},
#   {'customer_id': 'C01093',
#    'churn_probability': 0.5638,
#    'clv': 1413.11,
#    'priority_score': 0.0922},
#   {'customer_id': 'C01763',
#    'churn_probability': 0.8144,
#    'clv': 973.52,
#    'priority_score': 0.0917},
#   {'customer_id': 'C02941',
#    'churn_probability': 0.7683,
#    'clv': 1031.38,
#    'priority_score': 0.0916},
#   {'customer_id': 'C02700',
#    'churn_probability': 0.8087,
#    'clv': 970.78,
#    'priority_score': 0.0908},
#   {'customer_id': 'C02494',
#    'churn_probability': 0.8455,
#    'clv': 898.82,
#    'priority_score': 0.0878},
#   {'customer_id': 'C01648',
#    'churn_probability': 0.5104,
#    'clv': 1449.65,
#    'priority_score': 0.0857},
#   {'customer_id': 'C02635',
#    'churn_probability': 0.7927,
#    'clv': 916.87,
#    'priority_score': 0.084},
#   {'customer_id': 'C01743',
#    'churn_probability': 0.8695,
#    'clv': 832.42,
#    'priority_score': 0.0836},
#   {'customer_id': 'C01584',
#    'churn_probability': 0.7291,
#    'clv': 986.37,
#    'priority_score': 0.0832},
#   {'customer_id': 'C01013',
#    'churn_probability': 0.5057,
#    'clv': 1402.4,
#    'priority_score': 0.0821},
#   {'customer_id': 'C02795',
#    'churn_probability': 0.7081,
#    'clv': 999.28,
#    'priority_score': 0.0818},
#   {'customer_id': 'C00600',
#    'churn_probability': 0.4316,
#    'clv': 1612.77,
#    'priority_score': 0.0806},
#   {'customer_id': 'C02478',
#    'churn_probability': 0.9175,
#    'clv': 757.3,
#    'priority_score': 0.0802},
#   {'customer_id': 'C00863',
#    'churn_probability': 0.6025,
#    'clv': 1147.31,
#    'priority_score': 0.08},
#   {'customer_id': 'C02875',
#    'churn_probability': 0.7693,
#    'clv': 897.77,
#    'priority_score': 0.0798},
#   {'customer_id': 'C02655',
#    'churn_probability': 0.8211,
#    'clv': 838.78,
#    'priority_score': 0.0796},
#   {'customer_id': 'C01876',
#    'churn_probability': 0.8463,
#    'clv': 811.41,
#    'priority_score': 0.0793},
#   {'customer_id': 'C00174',
#    'churn_probability': 0.5252,
#    'clv': 1291.45,
#    'priority_score': 0.0785},
#   {'customer_id': 'C00148',
#    'churn_probability': 0.9101,
#    'clv': 745.38,
#    'priority_score': 0.0783},
#   {'customer_id': 'C02586',
#    'churn_probability': 0.4628,
#    'clv': 1458.32,
#    'priority_score': 0.0782},
#   {'customer_id': 'C00966',
#    'churn_probability': 0.737,
#    'clv': 908.08,
#    'priority_score': 0.0774},
#   {'customer_id': 'C00228',
#    'churn_probability': 0.6985,
#    'clv': 956.41,
#    'priority_score': 0.0772},
#   {'customer_id': 'C01191',
#    'churn_probability': 0.906,
#    'clv': 737.1,
#    'priority_score': 0.0771},
#   {'customer_id': 'C02359',
#    'churn_probability': 0.5855,
#    'clv': 1104.61,
#    'priority_score': 0.0748},
#   {'customer_id': 'C00323',
#    'churn_probability': 0.7284,
#    'clv': 886.67,
#    'priority_score': 0.0746},
#   {'customer_id': 'C01572',
#    'churn_probability': 0.9112,
#    'clv': 692.14,
#    'priority_score': 0.0728},
#   {'customer_id': 'C02636',
#    'churn_probability': 0.5942,
#    'clv': 1058.3,
#    'priority_score': 0.0727},
#   {'customer_id': 'C01738',
#    'churn_probability': 0.8553,
#    'clv': 733.79,
#    'priority_score': 0.0725},
#   {'customer_id': 'C00891',
#    'churn_probability': 0.7979,
#    'clv': 767.14,
#    'priority_score': 0.0707},
#   {'customer_id': 'C00072',
#    'churn_probability': 0.8905,
#    'clv': 682.54,
#    'priority_score': 0.0701},
#   {'customer_id': 'C00963',
#    'churn_probability': 0.8784,
#    'clv': 687.96,
#    'priority_score': 0.0697},
#   {'customer_id': 'C02489',
#    'churn_probability': 0.7322,
#    'clv': 823.35,
#    'priority_score': 0.0696},
#   {'customer_id': 'C01698',
#    'churn_probability': 0.6489,
#    'clv': 922.13,
#    'priority_score': 0.0692},
#   {'customer_id': 'C01905',
#    'churn_probability': 0.8163,
#    'clv': 726.83,
#    'priority_score': 0.0685},
#   {'customer_id': 'C02193',
#    'churn_probability': 0.7102,
#    'clv': 821.49,
#    'priority_score': 0.0674},
#   {'customer_id': 'C01815',
#    'churn_probability': 0.6902,
#    'clv': 844.63,
#    'priority_score': 0.0674},
#   {'customer_id': 'C02796',
#    'churn_probability': 0.7622,
#    'clv': 756.41,
#    'priority_score': 0.0666},
#   {'customer_id': 'C02901',
#    'churn_probability': 0.7521,
#    'clv': 756.55,
#    'priority_score': 0.0657},
#   {'customer_id': 'C01186',
#    'churn_probability': 0.893,
#    'clv': 629.74,
#    'priority_score': 0.0649},
#   {'customer_id': 'C01424',
#    'churn_probability': 0.8572,
#    'clv': 654.59,
#    'priority_score': 0.0647},
#   {'customer_id': 'C00102',
#    'churn_probability': 0.9175,
#    'clv': 607.37,
#    'priority_score': 0.0643},
#   {'customer_id': 'C00883',
#    'churn_probability': 0.8423,
#    'clv': 660.47,
#    'priority_score': 0.0642},
#   {'customer_id': 'C00793',
#    'churn_probability': 0.8205,
#    'clv': 673.23,
#    'priority_score': 0.0637},
#   {'customer_id': 'C01643',
#    'churn_probability': 0.4901,
#    'clv': 1105.36,
#    'priority_score': 0.0627},
#   {'customer_id': 'C02449',
#    'churn_probability': 0.8054,
#    'clv': 668.5,
#    'priority_score': 0.0621},
#   {'customer_id': 'C01490',
#    'churn_probability': 0.8282,
#    'clv': 648.83,
#    'priority_score': 0.062},
#   {'customer_id': 'C02999',
#    'churn_probability': 0.8652,
#    'clv': 615.81,
#    'priority_score': 0.0614},
#   {'customer_id': 'C01488',
#    'churn_probability': 0.5427,
#    'clv': 975.64,
#    'priority_score': 0.0612},
#   {'customer_id': 'C02616',
#    'churn_probability': 0.913,
#    'clv': 569.64,
#    'priority_score': 0.0599},
#   {'customer_id': 'C00262',
#    'churn_probability': 0.5209,
#    'clv': 991.73,
#    'priority_score': 0.0597},
#   {'customer_id': 'C01054',
#    'churn_probability': 0.8629,
#    'clv': 600.35,
#    'priority_score': 0.0597},
#   {'customer_id': 'C00147',
#    'churn_probability': 0.7796,
#    'clv': 653.68,
#    'priority_score': 0.0588},
#   {'customer_id': 'C01454',
#    'churn_probability': 0.9247,
#    'clv': 550.8,
#    'priority_score': 0.0587},
#   {'customer_id': 'C00071',
#    'churn_probability': 0.7393,
#    'clv': 682.29,
#    'priority_score': 0.0582}]}

# %%
rank_customers_for_retention(
    strategy="high_clv_high_churn_survival",
    top_k=100,
    prediction_df=prediction_df,
)
# Out:
# {'strategy': 'high_clv_high_churn_survival',
#  'customers': [{'customer_id': 'C00158',
#    'churn_probability': 0.9993,
#    'clv': 8614.52,
#    'priority_score': 0.9993},
#   {'customer_id': 'C02473',
#    'churn_probability': 0.9997,
#    'clv': 5681.23,
#    'priority_score': 0.6591},
#   {'customer_id': 'C01277',
#    'churn_probability': 0.9999,
#    'clv': 3833.37,
#    'priority_score': 0.4447},
#   {'customer_id': 'C01754',
#    'churn_probability': 0.9977,
#    'clv': 3626.54,
#    'priority_score': 0.4197},
#   {'customer_id': 'C02914',
#    'churn_probability': 0.9999,
#    'clv': 3568.36,
#    'priority_score': 0.4139},
#   {'customer_id': 'C00763',
#    'churn_probability': 0.9997,
#    'clv': 3285.43,
#    'priority_score': 0.381},
#   {'customer_id': 'C00789',
#    'churn_probability': 0.9999,
#    'clv': 2493.5,
#    'priority_score': 0.2891},
#   {'customer_id': 'C02934',
#    'churn_probability': 0.9997,
#    'clv': 2391.85,
#    'priority_score': 0.2772},
#   {'customer_id': 'C01864',
#    'churn_probability': 0.9976,
#    'clv': 2313.21,
#    'priority_score': 0.2675},
#   {'customer_id': 'C02865',
#    'churn_probability': 0.9971,
#    'clv': 2284.53,
#    'priority_score': 0.2641},
#   {'customer_id': 'C01189',
#    'churn_probability': 0.9996,
#    'clv': 2268.08,
#    'priority_score': 0.2628},
#   {'customer_id': 'C02347',
#    'churn_probability': 0.9982,
#    'clv': 2228.02,
#    'priority_score': 0.2578},
#   {'customer_id': 'C01131',
#    'churn_probability': 0.999,
#    'clv': 2123.12,
#    'priority_score': 0.2458},
#   {'customer_id': 'C01134',
#    'churn_probability': 0.9931,
#    'clv': 2117.58,
#    'priority_score': 0.2437},
#   {'customer_id': 'C00268',
#    'churn_probability': 0.9987,
#    'clv': 2034.38,
#    'priority_score': 0.2355},
#   {'customer_id': 'C02267',
#    'churn_probability': 0.9993,
#    'clv': 2001.81,
#    'priority_score': 0.2318},
#   {'customer_id': 'C02030',
#    'churn_probability': 0.9991,
#    'clv': 1996.79,
#    'priority_score': 0.2312},
#   {'customer_id': 'C02706',
#    'churn_probability': 0.9998,
#    'clv': 1892.06,
#    'priority_score': 0.2192},
#   {'customer_id': 'C00421',
#    'churn_probability': 0.9995,
#    'clv': 1888.03,
#    'priority_score': 0.2187},
#   {'customer_id': 'C01591',
#    'churn_probability': 0.9997,
#    'clv': 1847.41,
#    'priority_score': 0.214},
#   {'customer_id': 'C00397',
#    'churn_probability': 0.9988,
#    'clv': 1776.89,
#    'priority_score': 0.2056},
#   {'customer_id': 'C01793',
#    'churn_probability': 0.9996,
#    'clv': 1763.2,
#    'priority_score': 0.2042},
#   {'customer_id': 'C00423',
#    'churn_probability': 0.9995,
#    'clv': 1759.64,
#    'priority_score': 0.2038},
#   {'customer_id': 'C02658',
#    'churn_probability': 0.9984,
#    'clv': 1676.33,
#    'priority_score': 0.1939},
#   {'customer_id': 'C00599',
#    'churn_probability': 0.9992,
#    'clv': 1626.26,
#    'priority_score': 0.1882},
#   {'customer_id': 'C00600',
#    'churn_probability': 0.9988,
#    'clv': 1612.77,
#    'priority_score': 0.1866},
#   {'customer_id': 'C01986',
#    'churn_probability': 0.9981,
#    'clv': 1509.89,
#    'priority_score': 0.1745},
#   {'customer_id': 'C02014',
#    'churn_probability': 0.9965,
#    'clv': 1493.46,
#    'priority_score': 0.1723},
#   {'customer_id': 'C00490',
#    'churn_probability': 0.9997,
#    'clv': 1465.56,
#    'priority_score': 0.1697},
#   {'customer_id': 'C02586',
#    'churn_probability': 0.999,
#    'clv': 1458.32,
#    'priority_score': 0.1687},
#   {'customer_id': 'C01920',
#    'churn_probability': 0.9981,
#    'clv': 1449.22,
#    'priority_score': 0.1675},
#   {'customer_id': 'C01093',
#    'churn_probability': 0.9994,
#    'clv': 1413.11,
#    'priority_score': 0.1635},
#   {'customer_id': 'C01013',
#    'churn_probability': 0.9979,
#    'clv': 1402.4,
#    'priority_score': 0.162},
#   {'customer_id': 'C01648',
#    'churn_probability': 0.9598,
#    'clv': 1449.65,
#    'priority_score': 0.1611},
#   {'customer_id': 'C02905',
#    'churn_probability': 0.945,
#    'clv': 1431.82,
#    'priority_score': 0.1567},
#   {'customer_id': 'C00325',
#    'churn_probability': 0.9995,
#    'clv': 1311.61,
#    'priority_score': 0.1517},
#   {'customer_id': 'C01024',
#    'churn_probability': 0.9992,
#    'clv': 1307.78,
#    'priority_score': 0.1513},
#   {'customer_id': 'C00174',
#    'churn_probability': 0.9997,
#    'clv': 1291.45,
#    'priority_score': 0.1494},
#   {'customer_id': 'C02156',
#    'churn_probability': 0.9997,
#    'clv': 1228.69,
#    'priority_score': 0.1422},
#   {'customer_id': 'C00202',
#    'churn_probability': 0.9995,
#    'clv': 1198.5,
#    'priority_score': 0.1386},
#   {'customer_id': 'C02204',
#    'churn_probability': 0.9998,
#    'clv': 1193.74,
#    'priority_score': 0.1381},
#   {'customer_id': 'C00863',
#    'churn_probability': 0.9973,
#    'clv': 1147.31,
#    'priority_score': 0.1324},
#   {'customer_id': 'C02821',
#    'churn_probability': 0.9962,
#    'clv': 1142.07,
#    'priority_score': 0.1316},
#   {'customer_id': 'C02081',
#    'churn_probability': 0.9995,
#    'clv': 1115.29,
#    'priority_score': 0.129},
#   {'customer_id': 'C01643',
#    'churn_probability': 0.9997,
#    'clv': 1105.36,
#    'priority_score': 0.1278},
#   {'customer_id': 'C02359',
#    'churn_probability': 0.9977,
#    'clv': 1104.61,
#    'priority_score': 0.1275},
#   {'customer_id': 'C02832',
#    'churn_probability': 0.9991,
#    'clv': 1076.2,
#    'priority_score': 0.1244},
#   {'customer_id': 'C02636',
#    'churn_probability': 0.999,
#    'clv': 1058.3,
#    'priority_score': 0.1223},
#   {'customer_id': 'C00604',
#    'churn_probability': 0.9995,
#    'clv': 1056.64,
#    'priority_score': 0.1222},
#   {'customer_id': 'C02283',
#    'churn_probability': 0.9994,
#    'clv': 1037.43,
#    'priority_score': 0.1199},
#   {'customer_id': 'C02941',
#    'churn_probability': 0.9998,
#    'clv': 1031.38,
#    'priority_score': 0.1193},
#   {'customer_id': 'C01130',
#    'churn_probability': 0.9972,
#    'clv': 1026.43,
#    'priority_score': 0.1184},
#   {'customer_id': 'C02127',
#    'churn_probability': 0.9992,
#    'clv': 1022.21,
#    'priority_score': 0.1181},
#   {'customer_id': 'C02795',
#    'churn_probability': 0.9991,
#    'clv': 999.28,
#    'priority_score': 0.1154},
#   {'customer_id': 'C00262',
#    'churn_probability': 0.9985,
#    'clv': 991.73,
#    'priority_score': 0.1145},
#   {'customer_id': 'C01584',
#    'churn_probability': 0.9995,
#    'clv': 986.37,
#    'priority_score': 0.114},
#   {'customer_id': 'C01488',
#    'churn_probability': 0.9998,
#    'clv': 975.64,
#    'priority_score': 0.1128},
#   {'customer_id': 'C02700',
#    'churn_probability': 0.9982,
#    'clv': 970.78,
#    'priority_score': 0.112},
#   {'customer_id': 'C00228',
#    'churn_probability': 0.9958,
#    'clv': 956.41,
#    'priority_score': 0.1101},
#   {'customer_id': 'C00530',
#    'churn_probability': 0.999,
#    'clv': 952.91,
#    'priority_score': 0.1101},
#   {'customer_id': 'C01763',
#    'churn_probability': 0.9724,
#    'clv': 973.52,
#    'priority_score': 0.1095},
#   {'customer_id': 'C02364',
#    'churn_probability': 0.9992,
#    'clv': 940.79,
#    'priority_score': 0.1087},
#   {'customer_id': 'C00190',
#    'churn_probability': 0.9994,
#    'clv': 928.5,
#    'priority_score': 0.1073},
#   {'customer_id': 'C00988',
#    'churn_probability': 0.9983,
#    'clv': 926.84,
#    'priority_score': 0.107},
#   {'customer_id': 'C01336',
#    'churn_probability': 0.9994,
#    'clv': 921.66,
#    'priority_score': 0.1065},
#   {'customer_id': 'C02635',
#    'churn_probability': 0.9991,
#    'clv': 916.87,
#    'priority_score': 0.1059},
#   {'customer_id': 'C00310',
#    'churn_probability': 0.9974,
#    'clv': 917.58,
#    'priority_score': 0.1058},
#   {'customer_id': 'C00966',
#    'churn_probability': 0.9973,
#    'clv': 908.08,
#    'priority_score': 0.1047},
#   {'customer_id': 'C02494',
#    'churn_probability': 0.9992,
#    'clv': 898.82,
#    'priority_score': 0.1038},
#   {'customer_id': 'C01698',
#    'churn_probability': 0.9724,
#    'clv': 922.13,
#    'priority_score': 0.1036},
#   {'customer_id': 'C02875',
#    'churn_probability': 0.9965,
#    'clv': 897.77,
#    'priority_score': 0.1034},
#   {'customer_id': 'C00323',
#    'churn_probability': 0.9989,
#    'clv': 886.67,
#    'priority_score': 0.1024},
#   {'customer_id': 'C00240',
#    'churn_probability': 0.9977,
#    'clv': 851.26,
#    'priority_score': 0.0981},
#   {'customer_id': 'C01724',
#    'churn_probability': 0.9998,
#    'clv': 845.17,
#    'priority_score': 0.0976},
#   {'customer_id': 'C01839',
#    'churn_probability': 0.9985,
#    'clv': 841.98,
#    'priority_score': 0.0971},
#   {'customer_id': 'C02655',
#    'churn_probability': 0.9998,
#    'clv': 838.78,
#    'priority_score': 0.0969},
#   {'customer_id': 'C01743',
#    'churn_probability': 0.9987,
#    'clv': 832.42,
#    'priority_score': 0.096},
#   {'customer_id': 'C02489',
#    'churn_probability': 0.9981,
#    'clv': 823.35,
#    'priority_score': 0.0949},
#   {'customer_id': 'C02193',
#    'churn_probability': 0.9973,
#    'clv': 821.49,
#    'priority_score': 0.0946},
#   {'customer_id': 'C01876',
#    'churn_probability': 0.9956,
#    'clv': 811.41,
#    'priority_score': 0.0933},
#   {'customer_id': 'C01815',
#    'churn_probability': 0.9442,
#    'clv': 844.63,
#    'priority_score': 0.0921},
#   {'customer_id': 'C00130',
#    'churn_probability': 0.9995,
#    'clv': 780.77,
#    'priority_score': 0.0901},
#   {'customer_id': 'C00891',
#    'churn_probability': 0.9949,
#    'clv': 767.14,
#    'priority_score': 0.0881},
#   {'customer_id': 'C00975',
#    'churn_probability': 0.9981,
#    'clv': 757.17,
#    'priority_score': 0.0873},
#   {'customer_id': 'C02796',
#    'churn_probability': 0.9989,
#    'clv': 756.41,
#    'priority_score': 0.0872},
#   {'customer_id': 'C02901',
#    'churn_probability': 0.9984,
#    'clv': 756.55,
#    'priority_score': 0.0872},
#   {'customer_id': 'C02478',
#    'churn_probability': 0.9966,
#    'clv': 757.3,
#    'priority_score': 0.0871},
#   {'customer_id': 'C02847',
#    'churn_probability': 0.9952,
#    'clv': 753.77,
#    'priority_score': 0.0866},
#   {'customer_id': 'C00148',
#    'churn_probability': 0.9985,
#    'clv': 745.38,
#    'priority_score': 0.0859},
#   {'customer_id': 'C01191',
#    'churn_probability': 0.9972,
#    'clv': 737.1,
#    'priority_score': 0.0849},
#   {'customer_id': 'C01738',
#    'churn_probability': 0.9975,
#    'clv': 733.79,
#    'priority_score': 0.0845},
#   {'customer_id': 'C01905',
#    'churn_probability': 0.999,
#    'clv': 726.83,
#    'priority_score': 0.0838},
#   {'customer_id': 'C02501',
#    'churn_probability': 0.9979,
#    'clv': 718.03,
#    'priority_score': 0.0827},
#   {'customer_id': 'C02095',
#    'churn_probability': 0.9709,
#    'clv': 736.01,
#    'priority_score': 0.0825},
#   {'customer_id': 'C02326',
#    'churn_probability': 0.9989,
#    'clv': 696.04,
#    'priority_score': 0.0802},
#   {'customer_id': 'C01572',
#    'churn_probability': 0.998,
#    'clv': 692.14,
#    'priority_score': 0.0797},
#   {'customer_id': 'C00960',
#    'churn_probability': 0.997,
#    'clv': 689.84,
#    'priority_score': 0.0794},
#   {'customer_id': 'C00963',
#    'churn_probability': 0.9992,
#    'clv': 687.96,
#    'priority_score': 0.0793},
#   {'customer_id': 'C02040',
#    'churn_probability': 0.9994,
#    'clv': 679.52,
#    'priority_score': 0.0784},
#   {'customer_id': 'C00072',
#    'churn_probability': 0.9883,
#    'clv': 682.54,
#    'priority_score': 0.0778}]}

# %%
rank_customers_for_retention(
    strategy="low_p_alive",
    top_k=100,
    prediction_df=prediction_df,
)
# Out:
# {'strategy': 'low_p_alive',
#  'customers': [{'customer_id': 'C01116',
#    'churn_probability': None,
#    'clv': 268.35,
#    'priority_score': 1.0},
#   {'customer_id': 'C02578',
#    'churn_probability': None,
#    'clv': 128.09,
#    'priority_score': 1.0},
#   {'customer_id': 'C02576',
#    'churn_probability': None,
#    'clv': 388.76,
#    'priority_score': 1.0},
#   {'customer_id': 'C01312',
#    'churn_probability': None,
#    'clv': 152.18,
#    'priority_score': 1.0},
#   {'customer_id': 'C01317',
#    'churn_probability': None,
#    'clv': 303.93,
#    'priority_score': 1.0},
#   {'customer_id': 'C02570',
#    'churn_probability': None,
#    'clv': 123.49,
#    'priority_score': 1.0},
#   {'customer_id': 'C01333',
#    'churn_probability': None,
#    'clv': 568.52,
#    'priority_score': 1.0},
#   {'customer_id': 'C02905',
#    'churn_probability': None,
#    'clv': 1431.82,
#    'priority_score': 1.0},
#   {'customer_id': 'C01341',
#    'churn_probability': None,
#    'clv': 110.39,
#    'priority_score': 1.0},
#   {'customer_id': 'C01347',
#    'churn_probability': None,
#    'clv': 124.77,
#    'priority_score': 1.0},
#   {'customer_id': 'C02563',
#    'churn_probability': None,
#    'clv': 134.59,
#    'priority_score': 1.0},
#   {'customer_id': 'C00279',
#    'churn_probability': None,
#    'clv': 439.02,
#    'priority_score': 1.0},
#   {'customer_id': 'C02547',
#    'churn_probability': None,
#    'clv': 533.99,
#    'priority_score': 1.0},
#   {'customer_id': 'C01394',
#    'churn_probability': None,
#    'clv': 358.57,
#    'priority_score': 1.0},
#   {'customer_id': 'C01400',
#    'churn_probability': None,
#    'clv': 134.08,
#    'priority_score': 1.0},
#   {'customer_id': 'C01404',
#    'churn_probability': None,
#    'clv': 218.49,
#    'priority_score': 1.0},
#   {'customer_id': 'C00273',
#    'churn_probability': None,
#    'clv': 296.74,
#    'priority_score': 1.0},
#   {'customer_id': 'C01432',
#    'churn_probability': None,
#    'clv': 523.29,
#    'priority_score': 1.0},
#   {'customer_id': 'C01439',
#    'churn_probability': None,
#    'clv': 547.47,
#    'priority_score': 1.0},
#   {'customer_id': 'C01302',
#    'churn_probability': None,
#    'clv': 123.96,
#    'priority_score': 1.0},
#   {'customer_id': 'C02590',
#    'churn_probability': None,
#    'clv': 252.42,
#    'priority_score': 1.0},
#   {'customer_id': 'C02399',
#    'churn_probability': None,
#    'clv': 82.35,
#    'priority_score': 1.0},
#   {'customer_id': 'C01272',
#    'churn_probability': None,
#    'clv': 420.92,
#    'priority_score': 1.0},
#   {'customer_id': 'C01088',
#    'churn_probability': None,
#    'clv': 91.08,
#    'priority_score': 1.0},
#   {'customer_id': 'C01105',
#    'churn_probability': None,
#    'clv': 126.64,
#    'priority_score': 1.0},
#   {'customer_id': 'C00356',
#    'churn_probability': None,
#    'clv': 82.56,
#    'priority_score': 1.0},
#   {'customer_id': 'C00355',
#    'churn_probability': None,
#    'clv': 589.36,
#    'priority_score': 1.0},
#   {'customer_id': 'C01143',
#    'churn_probability': None,
#    'clv': 71.76,
#    'priority_score': 1.0},
#   {'customer_id': 'C01151',
#    'churn_probability': None,
#    'clv': 166.95,
#    'priority_score': 1.0},
#   {'customer_id': 'C01153',
#    'churn_probability': None,
#    'clv': 195.77,
#    'priority_score': 1.0},
#   {'customer_id': 'C01181',
#    'churn_probability': None,
#    'clv': 519.97,
#    'priority_score': 1.0},
#   {'customer_id': 'C01182',
#    'churn_probability': None,
#    'clv': 99.17,
#    'priority_score': 1.0},
#   {'customer_id': 'C01194',
#    'churn_probability': None,
#    'clv': 321.07,
#    'priority_score': 1.0},
#   {'customer_id': 'C00340',
#    'churn_probability': None,
#    'clv': 175.7,
#    'priority_score': 1.0},
#   {'customer_id': 'C02617',
#    'churn_probability': None,
#    'clv': 137.0,
#    'priority_score': 1.0},
#   {'customer_id': 'C02892',
#    'churn_probability': None,
#    'clv': 596.69,
#    'priority_score': 1.0},
#   {'customer_id': 'C01217',
#    'churn_probability': None,
#    'clv': 158.68,
#    'priority_score': 1.0},
#   {'customer_id': 'C01225',
#    'churn_probability': None,
#    'clv': 205.39,
#    'priority_score': 1.0},
#   {'customer_id': 'C02894',
#    'churn_probability': None,
#    'clv': 284.22,
#    'priority_score': 1.0},
#   {'customer_id': 'C01257',
#    'churn_probability': None,
#    'clv': 267.41,
#    'priority_score': 1.0},
#   {'customer_id': 'C02912',
#    'churn_probability': None,
#    'clv': 144.53,
#    'priority_score': 1.0},
#   {'customer_id': 'C01459',
#    'churn_probability': None,
#    'clv': 93.6,
#    'priority_score': 1.0},
#   {'customer_id': 'C01461',
#    'churn_probability': None,
#    'clv': 121.04,
#    'priority_score': 1.0},
#   {'customer_id': 'C01477',
#    'churn_probability': None,
#    'clv': 152.01,
#    'priority_score': 1.0},
#   {'customer_id': 'C02450',
#    'churn_probability': None,
#    'clv': 161.26,
#    'priority_score': 1.0},
#   {'customer_id': 'C01625',
#    'churn_probability': None,
#    'clv': 618.35,
#    'priority_score': 1.0},
#   {'customer_id': 'C01627',
#    'churn_probability': None,
#    'clv': 586.2,
#    'priority_score': 1.0},
#   {'customer_id': 'C01635',
#    'churn_probability': None,
#    'clv': 234.38,
#    'priority_score': 1.0},
#   {'customer_id': 'C01648',
#    'churn_probability': None,
#    'clv': 1449.65,
#    'priority_score': 1.0},
#   {'customer_id': 'C01653',
#    'churn_probability': None,
#    'clv': 238.65,
#    'priority_score': 1.0},
#   {'customer_id': 'C02433',
#    'churn_probability': None,
#    'clv': 120.47,
#    'priority_score': 1.0},
#   {'customer_id': 'C01675',
#    'churn_probability': None,
#    'clv': 350.19,
#    'priority_score': 1.0},
#   {'customer_id': 'C01692',
#    'churn_probability': None,
#    'clv': 181.75,
#    'priority_score': 1.0},
#   {'customer_id': 'C01698',
#    'churn_probability': None,
#    'clv': 922.13,
#    'priority_score': 1.0},
#   {'customer_id': 'C02416',
#    'churn_probability': None,
#    'clv': 199.02,
#    'priority_score': 1.0},
#   {'customer_id': 'C02411',
#    'churn_probability': None,
#    'clv': 140.45,
#    'priority_score': 1.0},
#   {'customer_id': 'C02937',
#    'churn_probability': None,
#    'clv': 101.36,
#    'priority_score': 1.0},
#   {'customer_id': 'C02402',
#    'churn_probability': None,
#    'clv': 63.58,
#    'priority_score': 1.0},
#   {'customer_id': 'C00180',
#    'churn_probability': None,
#    'clv': 58.91,
#    'priority_score': 1.0},
#   {'customer_id': 'C01730',
#    'churn_probability': None,
#    'clv': 368.68,
#    'priority_score': 1.0},
#   {'customer_id': 'C02939',
#    'churn_probability': None,
#    'clv': 416.97,
#    'priority_score': 1.0},
#   {'customer_id': 'C01616',
#    'churn_probability': None,
#    'clv': 277.74,
#    'priority_score': 1.0},
#   {'customer_id': 'C01610',
#    'churn_probability': None,
#    'clv': 159.14,
#    'priority_score': 1.0},
#   {'customer_id': 'C00217',
#    'churn_probability': None,
#    'clv': 324.35,
#    'priority_score': 1.0},
#   {'customer_id': 'C01531',
#    'churn_probability': None,
#    'clv': 112.48,
#    'priority_score': 1.0},
#   {'customer_id': 'C01481',
#    'churn_probability': None,
#    'clv': 155.28,
#    'priority_score': 1.0},
#   {'customer_id': 'C02512',
#    'churn_probability': None,
#    'clv': 294.31,
#    'priority_score': 1.0},
#   {'customer_id': 'C00253',
#    'churn_probability': None,
#    'clv': 175.8,
#    'priority_score': 1.0},
#   {'customer_id': 'C00250',
#    'churn_probability': None,
#    'clv': 184.95,
#    'priority_score': 1.0},
#   {'customer_id': 'C02497',
#    'churn_probability': None,
#    'clv': 265.72,
#    'priority_score': 1.0},
#   {'customer_id': 'C01530',
#    'churn_probability': None,
#    'clv': 64.43,
#    'priority_score': 1.0},
#   {'customer_id': 'C00244',
#    'churn_probability': None,
#    'clv': 281.79,
#    'priority_score': 1.0},
#   {'customer_id': 'C01541',
#    'churn_probability': None,
#    'clv': 394.04,
#    'priority_score': 1.0},
#   {'customer_id': 'C02922',
#    'churn_probability': None,
#    'clv': 235.26,
#    'priority_score': 1.0},
#   {'customer_id': 'C01543',
#    'churn_probability': None,
#    'clv': 311.84,
#    'priority_score': 1.0},
#   {'customer_id': 'C01550',
#    'churn_probability': None,
#    'clv': 97.26,
#    'priority_score': 1.0},
#   {'customer_id': 'C01552',
#    'churn_probability': None,
#    'clv': 185.23,
#    'priority_score': 1.0},
#   {'customer_id': 'C01562',
#    'churn_probability': None,
#    'clv': 89.08,
#    'priority_score': 1.0},
#   {'customer_id': 'C01570',
#    'churn_probability': None,
#    'clv': 178.29,
#    'priority_score': 1.0},
#   {'customer_id': 'C02465',
#    'churn_probability': None,
#    'clv': 296.18,
#    'priority_score': 1.0},
#   {'customer_id': 'C02459',
#    'churn_probability': None,
#    'clv': 183.74,
#    'priority_score': 1.0},
#   {'customer_id': 'C00367',
#    'churn_probability': None,
#    'clv': 229.48,
#    'priority_score': 1.0},
#   {'customer_id': 'C01080',
#    'churn_probability': None,
#    'clv': 56.98,
#    'priority_score': 1.0},
#   {'customer_id': 'C01073',
#    'churn_probability': None,
#    'clv': 431.48,
#    'priority_score': 1.0},
#   {'customer_id': 'C00832',
#    'churn_probability': None,
#    'clv': 211.8,
#    'priority_score': 1.0},
#   {'customer_id': 'C00486',
#    'churn_probability': None,
#    'clv': 87.47,
#    'priority_score': 1.0},
#   {'customer_id': 'C00770',
#    'churn_probability': None,
#    'clv': 649.5,
#    'priority_score': 1.0},
#   {'customer_id': 'C02846',
#    'churn_probability': None,
#    'clv': 110.4,
#    'priority_score': 1.0},
#   {'customer_id': 'C00772',
#    'churn_probability': None,
#    'clv': 215.07,
#    'priority_score': 1.0},
#   {'customer_id': 'C02753',
#    'churn_probability': None,
#    'clv': 253.23,
#    'priority_score': 1.0},
#   {'customer_id': 'C00784',
#    'churn_probability': None,
#    'clv': 242.09,
#    'priority_score': 1.0},
#   {'customer_id': 'C00480',
#    'churn_probability': None,
#    'clv': 238.64,
#    'priority_score': 1.0},
#   {'customer_id': 'C00787',
#    'churn_probability': None,
#    'clv': 124.51,
#    'priority_score': 1.0},
#   {'customer_id': 'C02740',
#    'churn_probability': None,
#    'clv': 146.21,
#    'priority_score': 1.0},
#   {'customer_id': 'C00795',
#    'churn_probability': None,
#    'clv': 396.32,
#    'priority_score': 1.0},
#   {'customer_id': 'C02739',
#    'churn_probability': None,
#    'clv': 215.96,
#    'priority_score': 1.0},
#   {'customer_id': 'C00801',
#    'churn_probability': None,
#    'clv': 184.89,
#    'priority_score': 1.0},
#   {'customer_id': 'C00805',
#    'churn_probability': None,
#    'clv': 123.21,
#    'priority_score': 1.0},
#   {'customer_id': 'C02737',
#    'churn_probability': None,
#    'clv': 50.58,
#    'priority_score': 1.0},
#   {'customer_id': 'C00465',
#    'churn_probability': None,
#    'clv': 180.56,
#    'priority_score': 1.0}]}

# %% [markdown]
# ## Compare Ranking

# %%
# Get top customers by strategy
out_clf = rank_customers_for_retention(
    strategy="high_clv_high_churn_classifier",
    top_k=100,
    prediction_df=prediction_df,
)

out_surv = rank_customers_for_retention(
    strategy="high_clv_high_churn_survival",
    top_k=100,
    prediction_df=prediction_df,
)

out_alive = rank_customers_for_retention(
    strategy="low_p_alive",
    top_k=100,
    prediction_df=prediction_df,
)

# %%
'''
# Rename columns for merging
df_clf = (
    pd.DataFrame(out_clf["customers"])
    [["customer_id", "priority_score"]]
    .rename(columns={"priority_score": "high_clv_high_churn_classifier"})
    .set_index("customer_id")
)

df_surv = (
    pd.DataFrame(out_surv["customers"])
    [["customer_id", "priority_score"]]
    .rename(columns={"priority_score": "high_clv_high_churn_survival"})
    .set_index("customer_id")
)

df_alive = (
    pd.DataFrame(out_alive["customers"])
    [["customer_id", "priority_score"]]
    .rename(columns={"priority_score": "low_p_alive"})
    .set_index("customer_id")
)

# Merge results
retention_scores_df = (
    df_clf
    .join(df_surv, how="outer")
    .join(df_alive, how="outer")
    .reset_index()
)

'''
# Out:
# '\n# Rename columns for merging\ndf_clf = (\n    pd.DataFrame(out_clf["customers"])\n    [["customer_id", "priority_score"]]\n    .rename(columns={"priority_score": "high_clv_high_churn_classifier"})\n    .set_index("customer_id")\n)\n\ndf_surv = (\n    pd.DataFrame(out_surv["customers"])\n    [["customer_id", "priority_score"]]\n    .rename(columns={"priority_score": "high_clv_high_churn_survival"})\n    .set_index("customer_id")\n)\n\ndf_alive = (\n    pd.DataFrame(out_alive["customers"])\n    [["customer_id", "priority_score"]]\n    .rename(columns={"priority_score": "low_p_alive"})\n    .set_index("customer_id")\n)\n\n# Merge results\nretention_scores_df = (\n    df_clf\n    .join(df_surv, how="outer")\n    .join(df_alive, how="outer")\n    .reset_index()\n)\n\n'

# %%
users_clf = set(c["customer_id"] for c in out_clf["customers"])
users_surv = set(c["customer_id"] for c in out_surv["customers"])
users_alive = set(c["customer_id"] for c in out_alive["customers"])

# %%
print("classifier:", len(users_clf))
print("survival:", len(users_surv))
print("low_p_alive:", len(users_alive))

print("classifier - survival:", len(users_clf - users_surv))

print("survival - low_p_alive:", len(users_surv - users_alive))

print("low_p_alive - classifier:", len(users_alive - users_clf))
# Out:
# classifier: 100
# survival: 100
# low_p_alive: 100
# classifier - survival: 13
# survival - low_p_alive: 97
# low_p_alive - classifier: 97

# %% [markdown]
# Observations:
# - The Classifier chose very similar users as the Survival Model. I find this to be quite surprising because both models have terrible recall for long prediction windows :). I was expecting them to be more uncertain in different ways, and therefore would select different users.
# - The BG-NBD model chose almost entirely different users from the other two methods. It is likely because the prediction window is shorter (immediate), so the accuracy is higher. Also, its training recall was also higher than the other two models.
#
# Final model selection:
# - After some thinking, I will choose the Survival approach. This is because the Survival models have the pros of LGBM (can improve performance and can predict the future) with a key difference: we do not have to train a model for each prediction window. We can just train one model.
# - On the other hand, while LGBM and Survival models have consistent results, the BG/NBD model results deviates too much from the other two models.
